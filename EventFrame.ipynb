# %% [markdown]
# ###Perform Inference with a MMAction2 recognizer
# ###Train a new recognizer with new dataset

# %%
# install dependencies: (use cu111 because colab has CUDA 11.1)
# !pip install torch==1.9.0+cu111 torchvision==0.10.0+cu111 -f https://download.pytorch.org/whl/torch_stable.html

# install mmcv-full thus we could use CUDA operators
# !pip install mmcv-full -f https://download.openmmlab.com/mmcv/dist/cu111/torch1.9.0/index.html

# Install mmaction2
# !rm -rf mmaction2
# !git clone https://github.com/open-mmlab/mmaction2.git
# %cd mmaction2

# !pip install -e .

# Install some optional requirements
# !pip install -r requirements/optional.txt

# %%
import torch, torchvision
import mmaction
from mmcv.ops import get_compiling_cuda_version, get_compiler_version

# %%
# !mkdir checkpoints
# !wget -c https://download.openmmlab.com/mmaction/recognition/tsm/tsm_r50_video_1x1x8_100e_kinetics400_rgb/tsm_r50_video_1x1x8_100e_kinetics400_rgb_20200702-a77f4328.pth \
      -O checkpoints/tsm_r50_video_1x1x8_100e_kinetics400_rgb_20200702-a77f4328.pth

# %%
# !mkdir checkpoints
# !wget -c https://download.openmmlab.com/mmaction/recognition/tin/tin_tsm_finetune_r50_1x1x8_50e_kinetics400_rgb/tin_tsm_finetune_r50_1x1x8_50e_kinetics400_rgb_20200810-4a146a70.pth \
      -O checkpoints/tin_tsm_finetune_r50_1x1x8_50e_kinetics400_rgb_20200810-4a146a70.pth

# %%
from mmaction.apis import inference_recognizer, init_recognizer

# Choose to use a config and initialize the recognizer
config = 'configs/recognition/tin/tin_tsm_finetune_r50_1x1x8_50e_kinetics400_rgb.py'
# Setup a checkpoint file to load
checkpoint = 'checkpoints/tin_tsm_finetune_r50_1x1x8_50e_kinetics400_rgb_20200810-4a146a70.pth'
# checkpoint = 'tutorial_exps/epoch_10.pth'
# Initialize the recognizer
model = init_recognizer(config, checkpoint, device='cuda:0') # pre-trained model
# Out:
# load checkpoint from local path: checkpoints/tin_tsm_finetune_r50_1x1x8_50e_kinetics400_rgb_20200810-4a146a70.pth

# %%
from google.colab import drive
drive.mount('/content/drive')
# drive/MyDrive/IEMS5910/rgbDataset
# Out:
# Mounted at /content/drive

# %%
# !mkdir checkpoints
# !cp ../drive/MyDrive/IEMS5910/tsm_r50_340x256_1x1x16_50e_kinetics400_rgb_20201011-2f27f229.pth checkpoints/

# %%
# !dir ../drive/MyDrive/IEMS5910/grayDataset
# Out:
# train  trainVideo.txt  val  valVideo.txt

# %%
# !rm -r rgbDataset

# %%
# !cp -r ../drive/MyDrive/IEMS5910/grayEvent50 rgbDataset

# %%
model

# %%
video = 'rgbDataset/train/V08a4.avi' # fps 25

label = 'tools/data/kinetics/label_map_k400.txt'
results = inference_recognizer(model, video) # model is Recognizer2D

labels = open(label).readlines()
labels = [x.strip() for x in labels]
results = [(labels[k[0]], k[1]) for k in results]

# %%
for result in results:
    print(f'{result[0]}: ', result[1])

# %%
# !apt-get -q install tree
# !tree rgbDataset

# %%
# !cat rgbDataset/trainVideo.txt

# %%
# !rm ./configs/recognition/tsm/tsm_r50_1x1x16_50e_kinetics400_rgb.py
# !cp ../drive/MyDrive/IEMS5910/tsm_r50_1x1x16_50e_kinetics400_rgb.py ./configs/recognition/tsm

# %%
# train_pipeline, test_pipeline, val_pipeline
# dict(type='DecordInit'),
# dict(type='DecordInit'),
from mmcv import Config
cfg = Config.fromfile('./configs/recognition/tsm/tsm_r50_1x1x16_50e_kinetics400_rgb.py')

# %%
from mmcv.runner import set_random_seed

# Modify dataset type and path
cfg.dataset_type = 'VideoDataset'
cfg.data_root = 'rgbDataset/train'
cfg.data_root_val = 'rgbDataset/val'
cfg.ann_file_train = 'rgbDataset/trainVideo.txt'
cfg.ann_file_val = 'rgbDataset/valVideo.txt'
cfg.ann_file_test = 'rgbDataset/valVideo.txt'

cfg.data.test.type = 'VideoDataset'
cfg.data.test.ann_file = 'rgbDataset/valVideo.txt'
cfg.data.test.data_prefix = 'rgbDataset/val'

cfg.data.train.type = 'VideoDataset'
cfg.data.train.ann_file = 'rgbDataset/trainVideo.txt'
cfg.data.train.data_prefix = 'rgbDataset/train'

cfg.data.val.type = 'VideoDataset'
cfg.data.val.ann_file = 'rgbDataset/valVideo.txt'
cfg.data.val.data_prefix = 'rgbDataset/val'

# The flag is used to determine whether it is omnisource training
cfg.setdefault('omnisource', False)
# Modify num classes of the model in cls_head
cfg.model.cls_head.num_classes = 31
# We can use the pre-trained TSN model
cfg.load_from = './checkpoints/tsm_r50_340x256_1x1x16_50e_kinetics400_rgb_20201011-2f27f229.pth'

# Set up working dir to save files and logs.
cfg.work_dir = './tutorial_exps'

# The original learning rate (LR) is set for 8-GPU training.
# We divide it by 8 since we only use one GPU.
# CUDA out of memory when cfg.data.videos_per_gpu = 6 
# cfg.data.videos_per_gpu = 8 originally
cfg.data.videos_per_gpu = cfg.data.videos_per_gpu 
cfg.optimizer.lr = cfg.optimizer.lr / 8
cfg.total_epochs = 20

# We can set the checkpoint saving interval to reduce the storage cost
cfg.checkpoint_config.interval = 5
# We can set the log print interval to reduce the the times of printing log
cfg.log_config.interval = 5

# Set seed thus the results are more reproducible
cfg.seed = 0
set_random_seed(0, deterministic=False)
cfg.gpu_ids = range(1)

# Save the best
cfg.evaluation.save_best='auto'


# We can initialize the logger for training and have a look
# at the final config used for training
print(f'Config:\n{cfg.pretty_text}')
# Out:
# Config:
# model = dict(
#     type='Recognizer2D',
#     backbone=dict(
#         type='ResNetTSM',
#         pretrained='torchvision://resnet50',
#         depth=50,
#         norm_eval=False,
#         shift_div=8,
#         num_segments=16),
#     cls_head=dict(
#         type='TSMHead',
#         num_classes=31,
#         in_channels=2048,
#         spatial_type='avg',
#         consensus=dict(type='AvgConsensus', dim=1),
#         dropout_ratio=0.5,
#         init_std=0.001,
#         is_shift=True,
#         num_segments=16),
#     train_cfg=None,
#     test_cfg=dict(average_clips='prob'))
# optimizer = dict(
#     type='SGD',
#     constructor='TSMOptimizerConstructor',
#     paramwise_cfg=dict(fc_lr5=True),
#     lr=0.0009375,
#     momentum=0.9,
#     weight_decay=0.0001)
# optimizer_config = dict(grad_clip=dict(max_norm=20, norm_type=2))
# lr_config = dict(policy='step', step=[20, 40])
# total_epochs = 20
# checkpoint_config = dict(interval=5)
# log_config = dict(interval=5, hooks=[dict(type='TextLoggerHook')])
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = './checkpoints/tsm_r50_340x256_1x1x16_50e_kinetics400_rgb_20201011-2f27f229.pth'
# resume_from = None
# workflow = [('train', 1)]
# opencv_num_threads = 0
# mp_start_method = 'fork'
# dataset_type = 'VideoDataset'
# data_root = 'rgbDataset/train'
# data_root_val = 'rgbDataset/val'
# ann_file_train = 'rgbDataset/trainVideo.txt'
# ann_file_val = 'rgbDataset/valVideo.txt'
# ann_file_test = 'rgbDataset/valVideo.txt'
# img_norm_cfg = dict(
#     mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_bgr=False)
# train_pipeline = [
#     dict(type='DecordInit'),
#     dict(type='SampleFrames', clip_len=1, frame_interval=1, num_clips=16),
#     dict(type='DecordDecode'),
#     dict(type='Resize', scale=(-1, 256)),
#     dict(
#         type='MultiScaleCrop',
#         input_size=224,
#         scales=(1, 0.875, 0.75, 0.66),
#         random_crop=False,
#         max_wh_scale_gap=1,
#         num_fixed_crops=13),
#     dict(type='Resize', scale=(224, 224), keep_ratio=False),
#     dict(type='Flip', flip_ratio=0.5),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_bgr=False),
#     dict(type='FormatShape', input_format='NCHW'),
#     dict(type='Collect', keys=['imgs', 'label'], meta_keys=[]),
#     dict(type='ToTensor', keys=['imgs', 'label'])
# ]
# val_pipeline = [
#     dict(type='DecordInit'),
#     dict(
#         type='SampleFrames',
#         clip_len=1,
#         frame_interval=1,
#         num_clips=16,
#         test_mode=True),
#     dict(type='DecordDecode'),
#     dict(type='Resize', scale=(-1, 256)),
#     dict(type='CenterCrop', crop_size=224),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_bgr=False),
#     dict(type='FormatShape', input_format='NCHW'),
#     dict(type='Collect', keys=['imgs', 'label'], meta_keys=[]),
#     dict(type='ToTensor', keys=['imgs'])
# ]
# test_pipeline = [
#     dict(type='DecordInit'),
#     dict(
#         type='SampleFrames',
#         clip_len=1,
#         frame_interval=1,
#         num_clips=16,
#         test_mode=True),
#     dict(type='DecordDecode'),
#     dict(type='Resize', scale=(-1, 256)),
#     dict(type='TenCrop', crop_size=224),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_bgr=False),
#     dict(type='FormatShape', input_format='NCHW'),
#     dict(type='Collect', keys=['imgs', 'label'], meta_keys=[]),
#     dict(type='ToTensor', keys=['imgs'])
# ]
# data = dict(
#     videos_per_gpu=6,
#     workers_per_gpu=2,
#     test_dataloader=dict(videos_per_gpu=1),
#     train=dict(
#         type='VideoDataset',
#         ann_file='rgbDataset/trainVideo.txt',
#         data_prefix='rgbDataset/train',
#         pipeline=[
#             dict(type='DecordInit'),
#             dict(
#                 type='SampleFrames',
#                 clip_len=1,
#                 frame_interval=1,
#                 num_clips=16),
#             dict(type='DecordDecode'),
#             dict(type='Resize', scale=(-1, 256)),
#             dict(
#                 type='MultiScaleCrop',
#                 input_size=224,
#                 scales=(1, 0.875, 0.75, 0.66),
#                 random_crop=False,
#                 max_wh_scale_gap=1,
#                 num_fixed_crops=13),
#             dict(type='Resize', scale=(224, 224), keep_ratio=False),
#             dict(type='Flip', flip_ratio=0.5),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_bgr=False),
#             dict(type='FormatShape', input_format='NCHW'),
#             dict(type='Collect', keys=['imgs', 'label'], meta_keys=[]),
#             dict(type='ToTensor', keys=['imgs', 'label'])
#         ]),
#     val=dict(
#         type='VideoDataset',
#         ann_file='rgbDataset/valVideo.txt',
#         data_prefix='rgbDataset/val',
#         pipeline=[
#             dict(type='DecordInit'),
#             dict(
#                 type='SampleFrames',
#                 clip_len=1,
#                 frame_interval=1,
#                 num_clips=16,
#                 test_mode=True),
#             dict(type='DecordDecode'),
#             dict(type='Resize', scale=(-1, 256)),
#             dict(type='CenterCrop', crop_size=224),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_bgr=False),
#             dict(type='FormatShape', input_format='NCHW'),
#             dict(type='Collect', keys=['imgs', 'label'], meta_keys=[]),
#             dict(type='ToTensor', keys=['imgs'])
#         ]),
#     test=dict(
#         type='VideoDataset',
#         ann_file='rgbDataset/valVideo.txt',
#         data_prefix='rgbDataset/val',
#         pipeline=[
#             dict(type='DecordInit'),
#             dict(
#                 type='SampleFrames',
#                 clip_len=1,
#                 frame_interval=1,
#                 num_clips=16,
#                 test_mode=True),
#             dict(type='DecordDecode'),
#             dict(type='Resize', scale=(-1, 256)),
#             dict(type='TenCrop', crop_size=224),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_bgr=False),
#             dict(type='FormatShape', input_format='NCHW'),
#             dict(type='Collect', keys=['imgs', 'label'], meta_keys=[]),
#             dict(type='ToTensor', keys=['imgs'])
#         ]))
# evaluation = dict(
#     interval=5,
#     metrics=['top_k_accuracy', 'mean_class_accuracy'],
#     save_best='auto')
# work_dir = './tutorial_exps'
# omnisource = False
# seed = 0
# gpu_ids = range(0, 1)

# %%
from mmaction.apis import inference_recognizer, init_recognizer
# checkpoint = 'tutorial_exps/best_top1_acc_epoch_15.pth'
checkpoint = '../drive/MyDrive/IEMS5910/logs_ouput/grayE50_tsm16/best_top1_acc_epoch_10.pth'
# checkpoint = '../drive/MyDrive/IEMS5910/logs_ouput/grayE_tsm16/best_top1_acc_epoch_10.pth'
# checkpoint = '../drive/MyDrive/IEMS5910/logs_ouput/gray_tsm16_10train3val/best_top1_acc_epoch_10.pth'
# checkpoint = '../drive/MyDrive/IEMS5910/logs_ouput/grayE10_tsm16/best_top1_acc_epoch_15.pth'
model = init_recognizer(cfg, checkpoint, device='cuda:0') # pre-trained model
# Out:
# load checkpoint from local path: ../drive/MyDrive/IEMS5910/logs_ouput/grayE50_tsm16/best_top1_acc_epoch_10.pth

# %%
inference_recognizer(model, "rgbDataset/val/V02a30.avi")
# a04,a05,a19,a20,a21,a23,a26,a30
# Out:
# False

# %%
label = '../drive/MyDrive/IEMS5910/idAction.txt'
labels = open(label).readlines()
labels = [x.strip().split('\t') for x in labels][1:]

# %%
import os
top1 = 0
top5 = 0
total = 0
for p,d,f in os.walk("rgbDataset/val"):
  for fn in f:
    if fn.endswith('.avi'):
      total += 1
      predSet = inference_recognizer(model,os.path.join(p,fn))
      pred = predSet[0][0] + 1
      predSet = [i[0]+1 for i in predSet]
      groundtruth = int(fn[fn.find('a')+1:fn.find('.')])
      # action = labels[groundtruth-1][1]
      if (groundtruth == pred):
        top1 += 1
      if (groundtruth in predSet):
        top5 += 1

# First we need to load correct dataset

# print('top1 accuracy in val event_tsm16: ',top1/total) # 0.4946
# print('top5 accuracy in val event_tsm16: ',top5/total) # 0.7957
# print('top1 accuracy in train event_tsm16: ',top1/total) # 0.6387
# print('top5 accuracy in train event_tsm16: ',top5/total) # 0.9354

# print('top1 accuracy in val gray_tsm16: ',top1/total) # 0.5269
# print('top5 accuracy in val gray_tsm16: ',top5/total) # 0.8817
# print('top1 accuracy in train gray_tsm16: ',top1/total) # 0.8742
# print('top5 accuracy in train gray_tsm16: ',top5/total) # 0.9935

# print('top1 accuracy in val grayE10_tsm16: ',top1/total) # 0.4409
# print('top5 accuracy in val grayE10_tsm16: ',top5/total) # 0.8925
# print('top1 accuracy in train grayE10_tsm16: ',top1/total) # 0.8839
# print('top5 accuracy in train grayE10_tsm16: ',top5/total) # 0.9903

# print('top1 accuracy in val grayE20_tsm16: ',top1/total) # 0.5484
# print('top5 accuracy in val grayE20_tsm16: ',top5/total) # 0.9032
# print('top1 accuracy in train grayE20_tsm16: ',top1/total) # 0.9194
# print('top5 accuracy in train grayE20_tsm16: ',top5/total) # 0.9935

# print('top1 accuracy in val grayE50_tsm16: ',top1/total) # 0.4946
# print('top5 accuracy in val grayE50_tsm16: ',top5/total) # 0.8817
# print('top1 accuracy in train grayE50_tsm16: ',top1/total) # 0.8484
# print('top5 accuracy in train grayE50_tsm16: ',top5/total) # 0.9903

# print('top1 accuracy in val grayE100_tsm16: ',top1/total) # 0.5699
# print('top5 accuracy in val grayE100_tsm16: ',top5/total) # 0.9032
# print('top1 accuracy in train grayE100_tsm16: ',top1/total) # 0.8194
# print('top5 accuracy in train grayE100_tsm16: ',top5/total) # 0.9871 

# top1 accuracy in val eflip_tsm16:  0.521505376344086
# top5 accuracy in val eflip_tsm16:  0.8387096774193549
# top1 accuracy in train eflip_tsm16:  0.7387096774193549
# top5 accuracy in train eflip_tsm16:  0.9725806451612903
# Out:
# top1 accuracy in train grayE50_tsm16:  0.8483870967741935
# top5 accuracy in train grayE50_tsm16:  0.9903225806451613

# %%
'''
train_pipeline = [
    dict(type='DecordInit'),
    dict(type='SampleFrames', clip_len=1, frame_interval=1, num_clips=8),
    dict(type='DecordDecode'),
    # dict(type='RawFrameDecode'),
    dict(type='Resize', scale=(-1, 256)),
''' 
import os.path as osp

from mmaction.datasets import build_dataset
from mmaction.models import build_model
from mmaction.apis import train_model

import mmcv

# Build the dataset
datasets = [build_dataset(cfg.data.train)]

# Build the recognizer
model = build_model(cfg.model, train_cfg=cfg.get('train_cfg'), test_cfg=cfg.get('test_cfg'))

# Create work_dir
mmcv.mkdir_or_exist(osp.abspath(cfg.work_dir))
train_model(model, datasets, cfg, distributed=False, validate=True)
# Out:
# 2022-12-08 02:00:55,043 - mmaction - INFO - These parameters in pretrained checkpoint are not loaded: {'fc.bias', 'fc.weight'}
# 2022-12-08 02:00:55,097 - mmaction - INFO - load checkpoint from local path: ./checkpoints/tsm_r50_340x256_1x1x16_50e_kinetics400_rgb_20201011-2f27f229.pth
# load checkpoint from torchvision path: torchvision://resnet50
# 2022-12-08 02:00:55,194 - mmaction - WARNING - The model and loaded state dict do not match exactly
#
# size mismatch for cls_head.fc_cls.weight: copying a param with shape torch.Size([400, 2048]) from checkpoint, the shape in current model is torch.Size([31, 2048]).
# size mismatch for cls_head.fc_cls.bias: copying a param with shape torch.Size([400]) from checkpoint, the shape in current model is torch.Size([31]).
# 2022-12-08 02:00:55,201 - mmaction - INFO - Start running, host: root@a9ffd3a0dfeb, work_dir: /content/mmaction2/tutorial_exps
# 2022-12-08 02:00:55,204 - mmaction - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) StepLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) StepLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_epoch:
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# 2022-12-08 02:00:55,206 - mmaction - INFO - workflow: [('train', 1)], max: 20 epochs
# 2022-12-08 02:00:55,212 - mmaction - INFO - Checkpoints will be saved to /content/mmaction2/tutorial_exps by HardDiskBackend.
# /usr/local/lib/python3.8/dist-packages/mmcv/runner/hooks/evaluation.py:226: UserWarning: runner.meta is None. Creating an empty one.
#   warnings.warn('runner.meta is None. Creating an empty one.')
# /usr/local/lib/python3.8/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# 2022-12-08 02:01:06,213 - mmaction - INFO - Epoch [1][5/52]	lr: 9.375e-04, eta: 0:37:55, time: 2.199, data_time: 0.771, memory: 10390, top1_acc: 0.0000, top5_acc: 0.1333, loss_cls: 3.4544, loss: 3.4544, grad_norm: 5.2565
# 2022-12-08 02:01:12,363 - mmaction - INFO - Epoch [1][10/52]	lr: 9.375e-04, eta: 0:29:25, time: 1.229, data_time: 0.004, memory: 10390, top1_acc: 0.0000, top5_acc: 0.1667, loss_cls: 3.5673, loss: 3.5673, grad_norm: 5.8984
# 2022-12-08 02:01:18,575 - mmaction - INFO - Epoch [1][15/52]	lr: 9.375e-04, eta: 0:26:36, time: 1.244, data_time: 0.008, memory: 10390, top1_acc: 0.0333, top5_acc: 0.0667, loss_cls: 3.6341, loss: 3.6341, grad_norm: 5.8113
# 2022-12-08 02:01:24,782 - mmaction - INFO - Epoch [1][20/52]	lr: 9.375e-04, eta: 0:25:07, time: 1.242, data_time: 0.001, memory: 10390, top1_acc: 0.1000, top5_acc: 0.2333, loss_cls: 3.4795, loss: 3.4795, grad_norm: 6.0444
# 2022-12-08 02:01:31,015 - mmaction - INFO - Epoch [1][25/52]	lr: 9.375e-04, eta: 0:24:13, time: 1.246, data_time: 0.002, memory: 10390, top1_acc: 0.0333, top5_acc: 0.1000, loss_cls: 3.5457, loss: 3.5457, grad_norm: 6.0112
# 2022-12-08 02:01:37,284 - mmaction - INFO - Epoch [1][30/52]	lr: 9.375e-04, eta: 0:23:36, time: 1.254, data_time: 0.002, memory: 10390, top1_acc: 0.0000, top5_acc: 0.1000, loss_cls: 3.7163, loss: 3.7163, grad_norm: 6.2363
# 2022-12-08 02:01:43,595 - mmaction - INFO - Epoch [1][35/52]	lr: 9.375e-04, eta: 0:23:09, time: 1.262, data_time: 0.004, memory: 10390, top1_acc: 0.0000, top5_acc: 0.1000, loss_cls: 3.6851, loss: 3.6851, grad_norm: 6.6207
# 2022-12-08 02:01:49,970 - mmaction - INFO - Epoch [1][40/52]	lr: 9.375e-04, eta: 0:22:48, time: 1.275, data_time: 0.001, memory: 10390, top1_acc: 0.1000, top5_acc: 0.1333, loss_cls: 3.6376, loss: 3.6376, grad_norm: 6.8850
# 2022-12-08 02:01:56,530 - mmaction - INFO - Epoch [1][45/52]	lr: 9.375e-04, eta: 0:22:35, time: 1.312, data_time: 0.003, memory: 10390, top1_acc: 0.0000, top5_acc: 0.1333, loss_cls: 3.5826, loss: 3.5826, grad_norm: 6.3910
# 2022-12-08 02:02:03,080 - mmaction - INFO - Epoch [1][50/52]	lr: 9.375e-04, eta: 0:22:23, time: 1.310, data_time: 0.003, memory: 10390, top1_acc: 0.0667, top5_acc: 0.1667, loss_cls: 3.6644, loss: 3.6644, grad_norm: 7.3388
# 2022-12-08 02:02:15,070 - mmaction - INFO - Epoch [2][5/52]	lr: 9.375e-04, eta: 0:22:17, time: 1.944, data_time: 0.629, memory: 10390, top1_acc: 0.0333, top5_acc: 0.2333, loss_cls: 3.3433, loss: 3.3433, grad_norm: 6.7963
# 2022-12-08 02:02:21,741 - mmaction - INFO - Epoch [2][10/52]	lr: 9.375e-04, eta: 0:22:09, time: 1.334, data_time: 0.008, memory: 10390, top1_acc: 0.1000, top5_acc: 0.3000, loss_cls: 3.3379, loss: 3.3379, grad_norm: 7.3974
# 2022-12-08 02:02:28,515 - mmaction - INFO - Epoch [2][15/52]	lr: 9.375e-04, eta: 0:22:01, time: 1.354, data_time: 0.008, memory: 10390, top1_acc: 0.0333, top5_acc: 0.1333, loss_cls: 3.4922, loss: 3.4922, grad_norm: 7.1718
# 2022-12-08 02:02:35,378 - mmaction - INFO - Epoch [2][20/52]	lr: 9.375e-04, eta: 0:21:56, time: 1.374, data_time: 0.010, memory: 10390, top1_acc: 0.1667, top5_acc: 0.4333, loss_cls: 3.1959, loss: 3.1959, grad_norm: 7.4513
# 2022-12-08 02:02:42,269 - mmaction - INFO - Epoch [2][25/52]	lr: 9.375e-04, eta: 0:21:50, time: 1.378, data_time: 0.010, memory: 10390, top1_acc: 0.1000, top5_acc: 0.2667, loss_cls: 3.4028, loss: 3.4028, grad_norm: 7.5271
# 2022-12-08 02:02:49,074 - mmaction - INFO - Epoch [2][30/52]	lr: 9.375e-04, eta: 0:21:43, time: 1.361, data_time: 0.010, memory: 10390, top1_acc: 0.1000, top5_acc: 0.2667, loss_cls: 3.3233, loss: 3.3233, grad_norm: 7.2757
# 2022-12-08 02:02:55,763 - mmaction - INFO - Epoch [2][35/52]	lr: 9.375e-04, eta: 0:21:35, time: 1.338, data_time: 0.004, memory: 10390, top1_acc: 0.0000, top5_acc: 0.3000, loss_cls: 3.4380, loss: 3.4380, grad_norm: 7.7006
# 2022-12-08 02:03:02,431 - mmaction - INFO - Epoch [2][40/52]	lr: 9.375e-04, eta: 0:21:27, time: 1.334, data_time: 0.007, memory: 10390, top1_acc: 0.1000, top5_acc: 0.2333, loss_cls: 3.4131, loss: 3.4131, grad_norm: 7.7189
# 2022-12-08 02:03:09,147 - mmaction - INFO - Epoch [2][45/52]	lr: 9.375e-04, eta: 0:21:19, time: 1.343, data_time: 0.009, memory: 10390, top1_acc: 0.1333, top5_acc: 0.3333, loss_cls: 3.2368, loss: 3.2368, grad_norm: 7.2636
# 2022-12-08 02:03:15,839 - mmaction - INFO - Epoch [2][50/52]	lr: 9.375e-04, eta: 0:21:12, time: 1.338, data_time: 0.004, memory: 10390, top1_acc: 0.0333, top5_acc: 0.2667, loss_cls: 3.3247, loss: 3.3247, grad_norm: 8.7481
# 2022-12-08 02:03:28,018 - mmaction - INFO - Epoch [3][5/52]	lr: 9.375e-04, eta: 0:21:06, time: 1.974, data_time: 0.656, memory: 10390, top1_acc: 0.1333, top5_acc: 0.4333, loss_cls: 3.0810, loss: 3.0810, grad_norm: 9.0872
# 2022-12-08 02:03:34,632 - mmaction - INFO - Epoch [3][10/52]	lr: 9.375e-04, eta: 0:20:57, time: 1.323, data_time: 0.005, memory: 10390, top1_acc: 0.0667, top5_acc: 0.2667, loss_cls: 3.1937, loss: 3.1937, grad_norm: 9.9998
# 2022-12-08 02:03:41,330 - mmaction - INFO - Epoch [3][15/52]	lr: 9.375e-04, eta: 0:20:50, time: 1.340, data_time: 0.010, memory: 10390, top1_acc: 0.0000, top5_acc: 0.3667, loss_cls: 3.2380, loss: 3.2380, grad_norm: 9.5479
# 2022-12-08 02:03:48,063 - mmaction - INFO - Epoch [3][20/52]	lr: 9.375e-04, eta: 0:20:43, time: 1.347, data_time: 0.007, memory: 10390, top1_acc: 0.1000, top5_acc: 0.2667, loss_cls: 3.2782, loss: 3.2782, grad_norm: 8.9610
# 2022-12-08 02:03:54,876 - mmaction - INFO - Epoch [3][25/52]	lr: 9.375e-04, eta: 0:20:36, time: 1.362, data_time: 0.006, memory: 10390, top1_acc: 0.0667, top5_acc: 0.3000, loss_cls: 3.3098, loss: 3.3098, grad_norm: 9.4365
# 2022-12-08 02:04:01,659 - mmaction - INFO - Epoch [3][30/52]	lr: 9.375e-04, eta: 0:20:29, time: 1.357, data_time: 0.007, memory: 10390, top1_acc: 0.1667, top5_acc: 0.4667, loss_cls: 2.9916, loss: 2.9916, grad_norm: 9.4814
# 2022-12-08 02:04:08,422 - mmaction - INFO - Epoch [3][35/52]	lr: 9.375e-04, eta: 0:20:22, time: 1.353, data_time: 0.018, memory: 10390, top1_acc: 0.1667, top5_acc: 0.3667, loss_cls: 3.0294, loss: 3.0294, grad_norm: 10.3302
# 2022-12-08 02:04:15,140 - mmaction - INFO - Epoch [3][40/52]	lr: 9.375e-04, eta: 0:20:15, time: 1.344, data_time: 0.010, memory: 10390, top1_acc: 0.1000, top5_acc: 0.4000, loss_cls: 2.9770, loss: 2.9770, grad_norm: 8.8096
# 2022-12-08 02:04:21,797 - mmaction - INFO - Epoch [3][45/52]	lr: 9.375e-04, eta: 0:20:07, time: 1.331, data_time: 0.008, memory: 10390, top1_acc: 0.1000, top5_acc: 0.4667, loss_cls: 2.9288, loss: 2.9288, grad_norm: 9.9291
# 2022-12-08 02:04:28,475 - mmaction - INFO - Epoch [3][50/52]	lr: 9.375e-04, eta: 0:20:00, time: 1.336, data_time: 0.007, memory: 10390, top1_acc: 0.1333, top5_acc: 0.3667, loss_cls: 3.0155, loss: 3.0155, grad_norm: 10.0017
# 2022-12-08 02:04:40,655 - mmaction - INFO - Epoch [4][5/52]	lr: 9.375e-04, eta: 0:19:53, time: 1.974, data_time: 0.651, memory: 10390, top1_acc: 0.1333, top5_acc: 0.4667, loss_cls: 2.9840, loss: 2.9840, grad_norm: 9.6665
# 2022-12-08 02:04:47,322 - mmaction - INFO - Epoch [4][10/52]	lr: 9.375e-04, eta: 0:19:45, time: 1.333, data_time: 0.009, memory: 10390, top1_acc: 0.2667, top5_acc: 0.6667, loss_cls: 2.5852, loss: 2.5852, grad_norm: 9.7017
# 2022-12-08 02:04:53,975 - mmaction - INFO - Epoch [4][15/52]	lr: 9.375e-04, eta: 0:19:38, time: 1.330, data_time: 0.001, memory: 10390, top1_acc: 0.2000, top5_acc: 0.5000, loss_cls: 2.9239, loss: 2.9239, grad_norm: 11.5060
# 2022-12-08 02:05:00,684 - mmaction - INFO - Epoch [4][20/52]	lr: 9.375e-04, eta: 0:19:31, time: 1.342, data_time: 0.008, memory: 10390, top1_acc: 0.1000, top5_acc: 0.5667, loss_cls: 2.8523, loss: 2.8523, grad_norm: 10.9386
# 2022-12-08 02:05:07,428 - mmaction - INFO - Epoch [4][25/52]	lr: 9.375e-04, eta: 0:19:24, time: 1.349, data_time: 0.004, memory: 10390, top1_acc: 0.1667, top5_acc: 0.6000, loss_cls: 2.8335, loss: 2.8335, grad_norm: 12.4877
# 2022-12-08 02:05:14,181 - mmaction - INFO - Epoch [4][30/52]	lr: 9.375e-04, eta: 0:19:17, time: 1.350, data_time: 0.006, memory: 10390, top1_acc: 0.1333, top5_acc: 0.5333, loss_cls: 2.9812, loss: 2.9812, grad_norm: 10.9927
# 2022-12-08 02:05:20,914 - mmaction - INFO - Epoch [4][35/52]	lr: 9.375e-04, eta: 0:19:10, time: 1.346, data_time: 0.007, memory: 10390, top1_acc: 0.2333, top5_acc: 0.5000, loss_cls: 2.6320, loss: 2.6320, grad_norm: 10.1952
# 2022-12-08 02:05:27,626 - mmaction - INFO - Epoch [4][40/52]	lr: 9.375e-04, eta: 0:19:03, time: 1.343, data_time: 0.011, memory: 10390, top1_acc: 0.2333, top5_acc: 0.6667, loss_cls: 2.4569, loss: 2.4569, grad_norm: 9.8422
# 2022-12-08 02:05:34,311 - mmaction - INFO - Epoch [4][45/52]	lr: 9.375e-04, eta: 0:18:56, time: 1.337, data_time: 0.006, memory: 10390, top1_acc: 0.0667, top5_acc: 0.4667, loss_cls: 2.9667, loss: 2.9667, grad_norm: 12.0508
# 2022-12-08 02:05:40,971 - mmaction - INFO - Epoch [4][50/52]	lr: 9.375e-04, eta: 0:18:49, time: 1.332, data_time: 0.008, memory: 10390, top1_acc: 0.1000, top5_acc: 0.4333, loss_cls: 3.1668, loss: 3.1668, grad_norm: 14.8613
# 2022-12-08 02:05:53,521 - mmaction - INFO - Epoch [5][5/52]	lr: 9.375e-04, eta: 0:18:42, time: 2.048, data_time: 0.713, memory: 10390, top1_acc: 0.3000, top5_acc: 0.7000, loss_cls: 2.4575, loss: 2.4575, grad_norm: 10.3697
# 2022-12-08 02:06:00,167 - mmaction - INFO - Epoch [5][10/52]	lr: 9.375e-04, eta: 0:18:35, time: 1.329, data_time: 0.004, memory: 10390, top1_acc: 0.1000, top5_acc: 0.6000, loss_cls: 2.7781, loss: 2.7781, grad_norm: 13.5845
# 2022-12-08 02:06:06,850 - mmaction - INFO - Epoch [5][15/52]	lr: 9.375e-04, eta: 0:18:28, time: 1.337, data_time: 0.006, memory: 10390, top1_acc: 0.1333, top5_acc: 0.3667, loss_cls: 3.0160, loss: 3.0160, grad_norm: 13.0040
# 2022-12-08 02:06:13,509 - mmaction - INFO - Epoch [5][20/52]	lr: 9.375e-04, eta: 0:18:20, time: 1.332, data_time: 0.003, memory: 10390, top1_acc: 0.3000, top5_acc: 0.5333, loss_cls: 2.5014, loss: 2.5014, grad_norm: 10.9134
# 2022-12-08 02:06:20,271 - mmaction - INFO - Epoch [5][25/52]	lr: 9.375e-04, eta: 0:18:13, time: 1.353, data_time: 0.014, memory: 10390, top1_acc: 0.2000, top5_acc: 0.6000, loss_cls: 2.7342, loss: 2.7342, grad_norm: 13.7273
# 2022-12-08 02:06:27,080 - mmaction - INFO - Epoch [5][30/52]	lr: 9.375e-04, eta: 0:18:07, time: 1.362, data_time: 0.005, memory: 10390, top1_acc: 0.2333, top5_acc: 0.7000, loss_cls: 2.4764, loss: 2.4764, grad_norm: 12.9524
# 2022-12-08 02:06:33,799 - mmaction - INFO - Epoch [5][35/52]	lr: 9.375e-04, eta: 0:18:00, time: 1.344, data_time: 0.007, memory: 10390, top1_acc: 0.1333, top5_acc: 0.6000, loss_cls: 2.6721, loss: 2.6721, grad_norm: 11.8896
# 2022-12-08 02:06:40,505 - mmaction - INFO - Epoch [5][40/52]	lr: 9.375e-04, eta: 0:17:53, time: 1.341, data_time: 0.010, memory: 10390, top1_acc: 0.2333, top5_acc: 0.6333, loss_cls: 2.7456, loss: 2.7456, grad_norm: 15.3942
# 2022-12-08 02:06:47,206 - mmaction - INFO - Epoch [5][45/52]	lr: 9.375e-04, eta: 0:17:46, time: 1.340, data_time: 0.012, memory: 10390, top1_acc: 0.1667, top5_acc: 0.5667, loss_cls: 2.9165, loss: 2.9165, grad_norm: 13.5096
# 2022-12-08 02:06:53,861 - mmaction - INFO - Epoch [5][50/52]	lr: 9.375e-04, eta: 0:17:39, time: 1.331, data_time: 0.006, memory: 10390, top1_acc: 0.1667, top5_acc: 0.5000, loss_cls: 2.9026, loss: 2.9026, grad_norm: 12.9164
# 2022-12-08 02:06:56,183 - mmaction - INFO - Saving checkpoint at 5 epochs
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 93/93, 6.5 task/s, elapsed: 14s, ETA:     0s
# 2022-12-08 02:07:11,671 - mmaction - INFO - Evaluating top_k_accuracy ...
# 2022-12-08 02:07:11,676 - mmaction - INFO -
# top1_acc	0.1505
# top5_acc	0.5376
# 2022-12-08 02:07:11,677 - mmaction - INFO - Evaluating mean_class_accuracy ...
# 2022-12-08 02:07:11,682 - mmaction - INFO -
# mean_acc	0.1505
# 2022-12-08 02:07:12,538 - mmaction - INFO - Now best checkpoint is saved as best_top1_acc_epoch_5.pth.
# 2022-12-08 02:07:12,540 - mmaction - INFO - Best top1_acc is 0.1505 at 5 epoch.
# 2022-12-08 02:07:12,547 - mmaction - INFO - Epoch(val) [5][16]	top1_acc: 0.1505, top5_acc: 0.5376, mean_class_accuracy: 0.1505
# 2022-12-08 02:07:22,520 - mmaction - INFO - Epoch [6][5/52]	lr: 9.375e-04, eta: 0:17:31, time: 1.993, data_time: 0.665, memory: 10390, top1_acc: 0.2667, top5_acc: 0.5667, loss_cls: 2.4371, loss: 2.4371, grad_norm: 12.3360
# 2022-12-08 02:07:29,258 - mmaction - INFO - Epoch [6][10/52]	lr: 9.375e-04, eta: 0:17:24, time: 1.348, data_time: 0.009, memory: 10390, top1_acc: 0.4000, top5_acc: 0.7000, loss_cls: 2.2959, loss: 2.2959, grad_norm: 12.2296
# 2022-12-08 02:07:36,117 - mmaction - INFO - Epoch [6][15/52]	lr: 9.375e-04, eta: 0:17:17, time: 1.372, data_time: 0.008, memory: 10390, top1_acc: 0.1667, top5_acc: 0.6667, loss_cls: 2.4736, loss: 2.4736, grad_norm: 11.1226
# 2022-12-08 02:07:43,022 - mmaction - INFO - Epoch [6][20/52]	lr: 9.375e-04, eta: 0:17:11, time: 1.381, data_time: 0.008, memory: 10390, top1_acc: 0.3667, top5_acc: 0.7333, loss_cls: 2.3093, loss: 2.3093, grad_norm: 12.8947
# 2022-12-08 02:07:49,858 - mmaction - INFO - Epoch [6][25/52]	lr: 9.375e-04, eta: 0:17:04, time: 1.367, data_time: 0.007, memory: 10390, top1_acc: 0.2000, top5_acc: 0.5333, loss_cls: 2.6101, loss: 2.6101, grad_norm: 11.8907
# 2022-12-08 02:07:56,642 - mmaction - INFO - Epoch [6][30/52]	lr: 9.375e-04, eta: 0:16:57, time: 1.357, data_time: 0.012, memory: 10390, top1_acc: 0.3333, top5_acc: 0.8000, loss_cls: 2.1675, loss: 2.1675, grad_norm: 12.6047
# 2022-12-08 02:08:03,324 - mmaction - INFO - Epoch [6][35/52]	lr: 9.375e-04, eta: 0:16:50, time: 1.336, data_time: 0.008, memory: 10390, top1_acc: 0.1333, top5_acc: 0.6000, loss_cls: 2.6147, loss: 2.6147, grad_norm: 13.1250
# 2022-12-08 02:08:09,972 - mmaction - INFO - Epoch [6][40/52]	lr: 9.375e-04, eta: 0:16:43, time: 1.330, data_time: 0.002, memory: 10390, top1_acc: 0.2667, top5_acc: 0.5333, loss_cls: 2.6614, loss: 2.6614, grad_norm: 12.5661
# 2022-12-08 02:08:16,719 - mmaction - INFO - Epoch [6][45/52]	lr: 9.375e-04, eta: 0:16:36, time: 1.349, data_time: 0.015, memory: 10390, top1_acc: 0.2333, top5_acc: 0.6333, loss_cls: 2.4800, loss: 2.4800, grad_norm: 14.6943
# 2022-12-08 02:08:23,332 - mmaction - INFO - Epoch [6][50/52]	lr: 9.375e-04, eta: 0:16:29, time: 1.322, data_time: 0.005, memory: 10390, top1_acc: 0.4000, top5_acc: 0.7333, loss_cls: 2.1089, loss: 2.1089, grad_norm: 12.9572
# 2022-12-08 02:08:35,588 - mmaction - INFO - Epoch [7][5/52]	lr: 9.375e-04, eta: 0:16:21, time: 1.987, data_time: 0.666, memory: 10390, top1_acc: 0.1667, top5_acc: 0.5333, loss_cls: 2.5746, loss: 2.5746, grad_norm: 13.5480
# 2022-12-08 02:08:42,240 - mmaction - INFO - Epoch [7][10/52]	lr: 9.375e-04, eta: 0:16:14, time: 1.330, data_time: 0.007, memory: 10390, top1_acc: 0.2667, top5_acc: 0.6667, loss_cls: 2.4125, loss: 2.4125, grad_norm: 14.2451
# 2022-12-08 02:08:48,943 - mmaction - INFO - Epoch [7][15/52]	lr: 9.375e-04, eta: 0:16:07, time: 1.341, data_time: 0.008, memory: 10390, top1_acc: 0.4000, top5_acc: 0.8000, loss_cls: 2.0077, loss: 2.0077, grad_norm: 12.4174
# 2022-12-08 02:08:55,716 - mmaction - INFO - Epoch [7][20/52]	lr: 9.375e-04, eta: 0:16:00, time: 1.352, data_time: 0.003, memory: 10390, top1_acc: 0.4000, top5_acc: 0.7333, loss_cls: 2.2702, loss: 2.2702, grad_norm: 13.2509
# 2022-12-08 02:09:02,532 - mmaction - INFO - Epoch [7][25/52]	lr: 9.375e-04, eta: 0:15:53, time: 1.366, data_time: 0.007, memory: 10390, top1_acc: 0.2667, top5_acc: 0.6667, loss_cls: 2.5513, loss: 2.5513, grad_norm: 15.0253
# 2022-12-08 02:09:09,336 - mmaction - INFO - Epoch [7][30/52]	lr: 9.375e-04, eta: 0:15:46, time: 1.361, data_time: 0.018, memory: 10390, top1_acc: 0.3000, top5_acc: 0.5333, loss_cls: 2.4083, loss: 2.4083, grad_norm: 14.0627
# 2022-12-08 02:09:16,054 - mmaction - INFO - Epoch [7][35/52]	lr: 9.375e-04, eta: 0:15:39, time: 1.343, data_time: 0.010, memory: 10390, top1_acc: 0.3667, top5_acc: 0.7333, loss_cls: 2.1416, loss: 2.1416, grad_norm: 12.2261
# 2022-12-08 02:09:22,732 - mmaction - INFO - Epoch [7][40/52]	lr: 9.375e-04, eta: 0:15:32, time: 1.336, data_time: 0.007, memory: 10390, top1_acc: 0.3000, top5_acc: 0.5667, loss_cls: 2.5085, loss: 2.5085, grad_norm: 13.5825
# 2022-12-08 02:09:29,427 - mmaction - INFO - Epoch [7][45/52]	lr: 9.375e-04, eta: 0:15:25, time: 1.339, data_time: 0.003, memory: 10390, top1_acc: 0.3333, top5_acc: 0.6000, loss_cls: 2.2493, loss: 2.2493, grad_norm: 13.3897
# 2022-12-08 02:09:36,101 - mmaction - INFO - Epoch [7][50/52]	lr: 9.375e-04, eta: 0:15:18, time: 1.335, data_time: 0.012, memory: 10390, top1_acc: 0.2000, top5_acc: 0.6667, loss_cls: 2.5761, loss: 2.5761, grad_norm: 15.4723
# 2022-12-08 02:09:48,367 - mmaction - INFO - Epoch [8][5/52]	lr: 9.375e-04, eta: 0:15:10, time: 1.990, data_time: 0.666, memory: 10390, top1_acc: 0.2667, top5_acc: 0.7000, loss_cls: 2.2029, loss: 2.2029, grad_norm: 14.3335
# 2022-12-08 02:09:55,035 - mmaction - INFO - Epoch [8][10/52]	lr: 9.375e-04, eta: 0:15:03, time: 1.334, data_time: 0.011, memory: 10390, top1_acc: 0.3000, top5_acc: 0.7000, loss_cls: 2.2798, loss: 2.2798, grad_norm: 15.7868
# 2022-12-08 02:10:01,773 - mmaction - INFO - Epoch [8][15/52]	lr: 9.375e-04, eta: 0:14:56, time: 1.348, data_time: 0.016, memory: 10390, top1_acc: 0.5333, top5_acc: 0.8333, loss_cls: 1.7516, loss: 1.7516, grad_norm: 13.9867
# 2022-12-08 02:10:08,479 - mmaction - INFO - Epoch [8][20/52]	lr: 9.375e-04, eta: 0:14:49, time: 1.341, data_time: 0.005, memory: 10390, top1_acc: 0.4000, top5_acc: 0.7333, loss_cls: 2.0082, loss: 2.0082, grad_norm: 13.5860
# 2022-12-08 02:10:15,239 - mmaction - INFO - Epoch [8][25/52]	lr: 9.375e-04, eta: 0:14:42, time: 1.352, data_time: 0.006, memory: 10390, top1_acc: 0.2333, top5_acc: 0.6333, loss_cls: 2.5577, loss: 2.5577, grad_norm: 15.4266
# 2022-12-08 02:10:22,006 - mmaction - INFO - Epoch [8][30/52]	lr: 9.375e-04, eta: 0:14:35, time: 1.353, data_time: 0.006, memory: 10390, top1_acc: 0.3333, top5_acc: 0.7333, loss_cls: 2.0733, loss: 2.0733, grad_norm: 13.9592
# 2022-12-08 02:10:28,748 - mmaction - INFO - Epoch [8][35/52]	lr: 9.375e-04, eta: 0:14:29, time: 1.348, data_time: 0.015, memory: 10390, top1_acc: 0.2667, top5_acc: 0.7000, loss_cls: 2.3460, loss: 2.3460, grad_norm: 15.9734
# 2022-12-08 02:10:35,476 - mmaction - INFO - Epoch [8][40/52]	lr: 9.375e-04, eta: 0:14:22, time: 1.346, data_time: 0.012, memory: 10390, top1_acc: 0.3333, top5_acc: 0.7000, loss_cls: 2.1615, loss: 2.1615, grad_norm: 14.4820
# 2022-12-08 02:10:42,160 - mmaction - INFO - Epoch [8][45/52]	lr: 9.375e-04, eta: 0:14:15, time: 1.337, data_time: 0.008, memory: 10390, top1_acc: 0.3000, top5_acc: 0.7000, loss_cls: 2.3659, loss: 2.3659, grad_norm: 16.8798
# 2022-12-08 02:10:48,801 - mmaction - INFO - Epoch [8][50/52]	lr: 9.375e-04, eta: 0:14:08, time: 1.328, data_time: 0.004, memory: 10390, top1_acc: 0.2667, top5_acc: 0.8000, loss_cls: 2.3053, loss: 2.3053, grad_norm: 16.5095
# 2022-12-08 02:11:01,438 - mmaction - INFO - Epoch [9][5/52]	lr: 9.375e-04, eta: 0:13:59, time: 2.041, data_time: 0.718, memory: 10390, top1_acc: 0.3000, top5_acc: 0.7667, loss_cls: 2.2552, loss: 2.2552, grad_norm: 15.5759
# 2022-12-08 02:11:08,108 - mmaction - INFO - Epoch [9][10/52]	lr: 9.375e-04, eta: 0:13:52, time: 1.334, data_time: 0.007, memory: 10390, top1_acc: 0.3000, top5_acc: 0.7000, loss_cls: 2.1637, loss: 2.1637, grad_norm: 15.6528
# 2022-12-08 02:11:14,832 - mmaction - INFO - Epoch [9][15/52]	lr: 9.375e-04, eta: 0:13:46, time: 1.344, data_time: 0.012, memory: 10390, top1_acc: 0.3333, top5_acc: 0.6333, loss_cls: 2.2748, loss: 2.2748, grad_norm: 14.3723
# 2022-12-08 02:11:21,560 - mmaction - INFO - Epoch [9][20/52]	lr: 9.375e-04, eta: 0:13:39, time: 1.346, data_time: 0.010, memory: 10390, top1_acc: 0.2667, top5_acc: 0.7000, loss_cls: 2.1775, loss: 2.1775, grad_norm: 13.3718
# 2022-12-08 02:11:28,252 - mmaction - INFO - Epoch [9][25/52]	lr: 9.375e-04, eta: 0:13:32, time: 1.338, data_time: 0.007, memory: 10390, top1_acc: 0.3000, top5_acc: 0.8667, loss_cls: 1.9213, loss: 1.9213, grad_norm: 14.2832
# 2022-12-08 02:11:35,023 - mmaction - INFO - Epoch [9][30/52]	lr: 9.375e-04, eta: 0:13:25, time: 1.354, data_time: 0.009, memory: 10390, top1_acc: 0.4000, top5_acc: 0.7333, loss_cls: 2.0331, loss: 2.0331, grad_norm: 15.9221
# 2022-12-08 02:11:41,733 - mmaction - INFO - Epoch [9][35/52]	lr: 9.375e-04, eta: 0:13:18, time: 1.342, data_time: 0.009, memory: 10390, top1_acc: 0.3333, top5_acc: 0.7000, loss_cls: 2.0921, loss: 2.0921, grad_norm: 15.5559
# 2022-12-08 02:11:48,445 - mmaction - INFO - Epoch [9][40/52]	lr: 9.375e-04, eta: 0:13:11, time: 1.342, data_time: 0.012, memory: 10390, top1_acc: 0.3667, top5_acc: 0.8000, loss_cls: 2.1980, loss: 2.1980, grad_norm: 15.5451
# 2022-12-08 02:11:55,081 - mmaction - INFO - Epoch [9][45/52]	lr: 9.375e-04, eta: 0:13:04, time: 1.327, data_time: 0.003, memory: 10390, top1_acc: 0.3333, top5_acc: 0.8667, loss_cls: 1.7106, loss: 1.7106, grad_norm: 12.3322
# 2022-12-08 02:12:01,687 - mmaction - INFO - Epoch [9][50/52]	lr: 9.375e-04, eta: 0:12:57, time: 1.321, data_time: 0.002, memory: 10390, top1_acc: 0.4000, top5_acc: 0.7333, loss_cls: 2.1451, loss: 2.1451, grad_norm: 15.6139
# 2022-12-08 02:12:14,676 - mmaction - INFO - Epoch [10][5/52]	lr: 9.375e-04, eta: 0:12:49, time: 2.135, data_time: 0.803, memory: 10390, top1_acc: 0.3000, top5_acc: 0.8667, loss_cls: 1.8900, loss: 1.8900, grad_norm: 15.8415
# 2022-12-08 02:12:21,344 - mmaction - INFO - Epoch [10][10/52]	lr: 9.375e-04, eta: 0:12:42, time: 1.334, data_time: 0.011, memory: 10390, top1_acc: 0.3667, top5_acc: 0.8667, loss_cls: 1.9127, loss: 1.9127, grad_norm: 14.4268
# 2022-12-08 02:12:28,050 - mmaction - INFO - Epoch [10][15/52]	lr: 9.375e-04, eta: 0:12:35, time: 1.341, data_time: 0.011, memory: 10390, top1_acc: 0.3333, top5_acc: 0.8333, loss_cls: 1.9744, loss: 1.9744, grad_norm: 15.5928
# 2022-12-08 02:12:34,811 - mmaction - INFO - Epoch [10][20/52]	lr: 9.375e-04, eta: 0:12:29, time: 1.352, data_time: 0.006, memory: 10390, top1_acc: 0.3000, top5_acc: 0.8000, loss_cls: 2.2158, loss: 2.2158, grad_norm: 15.4566
# 2022-12-08 02:12:41,529 - mmaction - INFO - Epoch [10][25/52]	lr: 9.375e-04, eta: 0:12:22, time: 1.344, data_time: 0.007, memory: 10390, top1_acc: 0.3667, top5_acc: 0.7667, loss_cls: 2.0613, loss: 2.0613, grad_norm: 15.3771
# 2022-12-08 02:12:48,279 - mmaction - INFO - Epoch [10][30/52]	lr: 9.375e-04, eta: 0:12:15, time: 1.350, data_time: 0.008, memory: 10390, top1_acc: 0.4667, top5_acc: 0.7333, loss_cls: 1.7587, loss: 1.7587, grad_norm: 14.8847
# 2022-12-08 02:12:55,034 - mmaction - INFO - Epoch [10][35/52]	lr: 9.375e-04, eta: 0:12:08, time: 1.351, data_time: 0.012, memory: 10390, top1_acc: 0.3333, top5_acc: 0.7667, loss_cls: 1.9158, loss: 1.9158, grad_norm: 14.6096
# 2022-12-08 02:13:01,711 - mmaction - INFO - Epoch [10][40/52]	lr: 9.375e-04, eta: 0:12:01, time: 1.335, data_time: 0.007, memory: 10390, top1_acc: 0.5000, top5_acc: 0.8333, loss_cls: 1.7770, loss: 1.7770, grad_norm: 13.9045
# 2022-12-08 02:13:08,375 - mmaction - INFO - Epoch [10][45/52]	lr: 9.375e-04, eta: 0:11:54, time: 1.333, data_time: 0.009, memory: 10390, top1_acc: 0.4667, top5_acc: 0.6333, loss_cls: 2.0096, loss: 2.0096, grad_norm: 15.8432
# 2022-12-08 02:13:15,038 - mmaction - INFO - Epoch [10][50/52]	lr: 9.375e-04, eta: 0:11:47, time: 1.333, data_time: 0.008, memory: 10390, top1_acc: 0.4000, top5_acc: 0.7667, loss_cls: 2.0139, loss: 2.0139, grad_norm: 15.8703
# 2022-12-08 02:13:17,353 - mmaction - INFO - Saving checkpoint at 10 epochs
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 93/93, 7.1 task/s, elapsed: 13s, ETA:     0s
# 2022-12-08 02:13:31,383 - mmaction - INFO - Evaluating top_k_accuracy ...
# 2022-12-08 02:13:31,390 - mmaction - INFO -
# top1_acc	0.2366
# top5_acc	0.6559
# 2022-12-08 02:13:31,391 - mmaction - INFO - Evaluating mean_class_accuracy ...
# 2022-12-08 02:13:31,393 - mmaction - INFO -
# mean_acc	0.2366
# 2022-12-08 02:13:31,427 - mmaction - INFO - The previous best checkpoint /content/mmaction2/tutorial_exps/best_top1_acc_epoch_5.pth was removed
# 2022-12-08 02:13:32,277 - mmaction - INFO - Now best checkpoint is saved as best_top1_acc_epoch_10.pth.
# 2022-12-08 02:13:32,290 - mmaction - INFO - Best top1_acc is 0.2366 at 10 epoch.
# 2022-12-08 02:13:32,292 - mmaction - INFO - Epoch(val) [10][16]	top1_acc: 0.2366, top5_acc: 0.6559, mean_class_accuracy: 0.2366
# 2022-12-08 02:13:42,075 - mmaction - INFO - Epoch [11][5/52]	lr: 9.375e-04, eta: 0:11:38, time: 1.952, data_time: 0.628, memory: 10390, top1_acc: 0.3000, top5_acc: 0.8000, loss_cls: 1.8005, loss: 1.8005, grad_norm: 14.3935
# 2022-12-08 02:13:48,749 - mmaction - INFO - Epoch [11][10/52]	lr: 9.375e-04, eta: 0:11:31, time: 1.336, data_time: 0.006, memory: 10390, top1_acc: 0.3000, top5_acc: 0.8667, loss_cls: 1.8702, loss: 1.8702, grad_norm: 15.8174
# 2022-12-08 02:13:55,510 - mmaction - INFO - Epoch [11][15/52]	lr: 9.375e-04, eta: 0:11:25, time: 1.352, data_time: 0.002, memory: 10390, top1_acc: 0.4667, top5_acc: 0.8333, loss_cls: 1.8778, loss: 1.8778, grad_norm: 15.6352
# 2022-12-08 02:14:02,381 - mmaction - INFO - Epoch [11][20/52]	lr: 9.375e-04, eta: 0:11:18, time: 1.374, data_time: 0.008, memory: 10390, top1_acc: 0.5333, top5_acc: 0.9000, loss_cls: 1.4892, loss: 1.4892, grad_norm: 14.8965
# 2022-12-08 02:14:09,203 - mmaction - INFO - Epoch [11][25/52]	lr: 9.375e-04, eta: 0:11:11, time: 1.364, data_time: 0.003, memory: 10390, top1_acc: 0.4667, top5_acc: 0.9333, loss_cls: 1.6887, loss: 1.6887, grad_norm: 18.7395
# 2022-12-08 02:14:15,978 - mmaction - INFO - Epoch [11][30/52]	lr: 9.375e-04, eta: 0:11:04, time: 1.355, data_time: 0.008, memory: 10390, top1_acc: 0.4667, top5_acc: 0.7333, loss_cls: 1.9469, loss: 1.9469, grad_norm: 15.6905
# 2022-12-08 02:14:22,634 - mmaction - INFO - Epoch [11][35/52]	lr: 9.375e-04, eta: 0:10:57, time: 1.331, data_time: 0.001, memory: 10390, top1_acc: 0.3000, top5_acc: 0.7667, loss_cls: 2.3436, loss: 2.3436, grad_norm: 17.9007
# 2022-12-08 02:14:29,319 - mmaction - INFO - Epoch [11][40/52]	lr: 9.375e-04, eta: 0:10:51, time: 1.337, data_time: 0.005, memory: 10390, top1_acc: 0.3000, top5_acc: 0.8667, loss_cls: 2.0398, loss: 2.0398, grad_norm: 17.4102
# 2022-12-08 02:14:35,950 - mmaction - INFO - Epoch [11][45/52]	lr: 9.375e-04, eta: 0:10:44, time: 1.326, data_time: 0.005, memory: 10390, top1_acc: 0.3333, top5_acc: 0.7333, loss_cls: 2.2307, loss: 2.2307, grad_norm: 18.9732
# 2022-12-08 02:14:42,606 - mmaction - INFO - Epoch [11][50/52]	lr: 9.375e-04, eta: 0:10:37, time: 1.331, data_time: 0.007, memory: 10390, top1_acc: 0.5000, top5_acc: 0.7333, loss_cls: 2.0115, loss: 2.0115, grad_norm: 16.3741
# 2022-12-08 02:14:54,825 - mmaction - INFO - Epoch [12][5/52]	lr: 9.375e-04, eta: 0:10:28, time: 1.981, data_time: 0.652, memory: 10390, top1_acc: 0.4667, top5_acc: 0.9000, loss_cls: 1.8130, loss: 1.8130, grad_norm: 17.6234
# 2022-12-08 02:15:01,482 - mmaction - INFO - Epoch [12][10/52]	lr: 9.375e-04, eta: 0:10:21, time: 1.331, data_time: 0.004, memory: 10390, top1_acc: 0.6333, top5_acc: 0.8667, loss_cls: 1.3667, loss: 1.3667, grad_norm: 12.2726
# 2022-12-08 02:15:08,126 - mmaction - INFO - Epoch [12][15/52]	lr: 9.375e-04, eta: 0:10:14, time: 1.329, data_time: 0.001, memory: 10390, top1_acc: 0.4333, top5_acc: 0.8333, loss_cls: 1.5232, loss: 1.5232, grad_norm: 16.0864
# 2022-12-08 02:15:14,896 - mmaction - INFO - Epoch [12][20/52]	lr: 9.375e-04, eta: 0:10:07, time: 1.354, data_time: 0.011, memory: 10390, top1_acc: 0.4333, top5_acc: 0.8000, loss_cls: 1.6669, loss: 1.6669, grad_norm: 14.2584
# 2022-12-08 02:15:21,701 - mmaction - INFO - Epoch [12][25/52]	lr: 9.375e-04, eta: 0:10:00, time: 1.360, data_time: 0.006, memory: 10390, top1_acc: 0.5000, top5_acc: 0.8333, loss_cls: 1.7633, loss: 1.7633, grad_norm: 18.5274
# 2022-12-08 02:15:28,482 - mmaction - INFO - Epoch [12][30/52]	lr: 9.375e-04, eta: 0:09:53, time: 1.357, data_time: 0.007, memory: 10390, top1_acc: 0.4000, top5_acc: 0.6333, loss_cls: 1.9977, loss: 1.9977, grad_norm: 16.1627
# 2022-12-08 02:15:35,209 - mmaction - INFO - Epoch [12][35/52]	lr: 9.375e-04, eta: 0:09:47, time: 1.345, data_time: 0.009, memory: 10390, top1_acc: 0.4667, top5_acc: 0.7333, loss_cls: 1.9426, loss: 1.9426, grad_norm: 16.9063
# 2022-12-08 02:15:41,941 - mmaction - INFO - Epoch [12][40/52]	lr: 9.375e-04, eta: 0:09:40, time: 1.347, data_time: 0.009, memory: 10390, top1_acc: 0.4333, top5_acc: 0.8000, loss_cls: 1.7238, loss: 1.7238, grad_norm: 15.3314
# 2022-12-08 02:15:48,627 - mmaction - INFO - Epoch [12][45/52]	lr: 9.375e-04, eta: 0:09:33, time: 1.337, data_time: 0.013, memory: 10390, top1_acc: 0.4333, top5_acc: 0.9667, loss_cls: 1.5662, loss: 1.5662, grad_norm: 15.0033
# 2022-12-08 02:15:55,270 - mmaction - INFO - Epoch [12][50/52]	lr: 9.375e-04, eta: 0:09:26, time: 1.329, data_time: 0.008, memory: 10390, top1_acc: 0.4667, top5_acc: 0.8000, loss_cls: 1.8561, loss: 1.8561, grad_norm: 17.6613
# 2022-12-08 02:16:07,603 - mmaction - INFO - Epoch [13][5/52]	lr: 9.375e-04, eta: 0:09:17, time: 1.987, data_time: 0.663, memory: 10390, top1_acc: 0.5333, top5_acc: 0.8667, loss_cls: 1.5749, loss: 1.5749, grad_norm: 13.3386
# 2022-12-08 02:16:14,283 - mmaction - INFO - Epoch [13][10/52]	lr: 9.375e-04, eta: 0:09:10, time: 1.336, data_time: 0.008, memory: 10390, top1_acc: 0.3333, top5_acc: 0.9333, loss_cls: 1.8589, loss: 1.8589, grad_norm: 18.5574
# 2022-12-08 02:16:21,009 - mmaction - INFO - Epoch [13][15/52]	lr: 9.375e-04, eta: 0:09:03, time: 1.345, data_time: 0.011, memory: 10390, top1_acc: 0.4333, top5_acc: 0.8333, loss_cls: 1.6938, loss: 1.6938, grad_norm: 18.5222
# 2022-12-08 02:16:27,716 - mmaction - INFO - Epoch [13][20/52]	lr: 9.375e-04, eta: 0:08:56, time: 1.341, data_time: 0.007, memory: 10390, top1_acc: 0.6667, top5_acc: 0.7667, loss_cls: 1.5420, loss: 1.5420, grad_norm: 16.2352
# 2022-12-08 02:16:34,452 - mmaction - INFO - Epoch [13][25/52]	lr: 9.375e-04, eta: 0:08:50, time: 1.347, data_time: 0.004, memory: 10390, top1_acc: 0.5000, top5_acc: 0.9333, loss_cls: 1.3448, loss: 1.3448, grad_norm: 15.8419
# 2022-12-08 02:16:41,190 - mmaction - INFO - Epoch [13][30/52]	lr: 9.375e-04, eta: 0:08:43, time: 1.347, data_time: 0.004, memory: 10390, top1_acc: 0.5333, top5_acc: 0.8000, loss_cls: 1.7294, loss: 1.7294, grad_norm: 14.3069
# 2022-12-08 02:16:47,921 - mmaction - INFO - Epoch [13][35/52]	lr: 9.375e-04, eta: 0:08:36, time: 1.346, data_time: 0.011, memory: 10390, top1_acc: 0.5667, top5_acc: 0.9667, loss_cls: 1.2908, loss: 1.2908, grad_norm: 14.0404
# 2022-12-08 02:16:54,603 - mmaction - INFO - Epoch [13][40/52]	lr: 9.375e-04, eta: 0:08:29, time: 1.336, data_time: 0.007, memory: 10390, top1_acc: 0.4667, top5_acc: 0.8333, loss_cls: 1.8427, loss: 1.8427, grad_norm: 17.6237
# 2022-12-08 02:17:01,265 - mmaction - INFO - Epoch [13][45/52]	lr: 9.375e-04, eta: 0:08:22, time: 1.332, data_time: 0.007, memory: 10390, top1_acc: 0.3333, top5_acc: 0.6333, loss_cls: 2.2723, loss: 2.2723, grad_norm: 17.9358
# 2022-12-08 02:17:07,934 - mmaction - INFO - Epoch [13][50/52]	lr: 9.375e-04, eta: 0:08:16, time: 1.334, data_time: 0.010, memory: 10390, top1_acc: 0.4000, top5_acc: 0.7000, loss_cls: 1.9597, loss: 1.9597, grad_norm: 17.8155
# 2022-12-08 02:17:20,816 - mmaction - INFO - Epoch [14][5/52]	lr: 9.375e-04, eta: 0:08:07, time: 2.109, data_time: 0.782, memory: 10390, top1_acc: 0.4000, top5_acc: 0.8000, loss_cls: 1.8562, loss: 1.8562, grad_norm: 16.8580
# 2022-12-08 02:17:27,442 - mmaction - INFO - Epoch [14][10/52]	lr: 9.375e-04, eta: 0:08:00, time: 1.325, data_time: 0.001, memory: 10390, top1_acc: 0.5667, top5_acc: 0.9000, loss_cls: 1.2829, loss: 1.2829, grad_norm: 13.9989
# 2022-12-08 02:17:34,205 - mmaction - INFO - Epoch [14][15/52]	lr: 9.375e-04, eta: 0:07:53, time: 1.353, data_time: 0.004, memory: 10390, top1_acc: 0.4667, top5_acc: 0.7667, loss_cls: 1.6885, loss: 1.6885, grad_norm: 15.5527
# 2022-12-08 02:17:40,919 - mmaction - INFO - Epoch [14][20/52]	lr: 9.375e-04, eta: 0:07:46, time: 1.343, data_time: 0.008, memory: 10390, top1_acc: 0.5667, top5_acc: 0.9000, loss_cls: 1.6070, loss: 1.6070, grad_norm: 13.5401
# 2022-12-08 02:17:47,644 - mmaction - INFO - Epoch [14][25/52]	lr: 9.375e-04, eta: 0:07:39, time: 1.345, data_time: 0.013, memory: 10390, top1_acc: 0.4667, top5_acc: 0.9667, loss_cls: 1.5374, loss: 1.5374, grad_norm: 17.9905
# 2022-12-08 02:17:54,382 - mmaction - INFO - Epoch [14][30/52]	lr: 9.375e-04, eta: 0:07:33, time: 1.348, data_time: 0.009, memory: 10390, top1_acc: 0.6000, top5_acc: 0.8333, loss_cls: 1.4509, loss: 1.4509, grad_norm: 14.5373
# 2022-12-08 02:18:01,086 - mmaction - INFO - Epoch [14][35/52]	lr: 9.375e-04, eta: 0:07:26, time: 1.341, data_time: 0.006, memory: 10390, top1_acc: 0.4667, top5_acc: 0.8000, loss_cls: 1.5747, loss: 1.5747, grad_norm: 16.4772
# 2022-12-08 02:18:07,763 - mmaction - INFO - Epoch [14][40/52]	lr: 9.375e-04, eta: 0:07:19, time: 1.335, data_time: 0.005, memory: 10390, top1_acc: 0.4667, top5_acc: 0.8333, loss_cls: 1.4519, loss: 1.4519, grad_norm: 15.8627
# 2022-12-08 02:18:14,454 - mmaction - INFO - Epoch [14][45/52]	lr: 9.375e-04, eta: 0:07:12, time: 1.338, data_time: 0.001, memory: 10390, top1_acc: 0.3667, top5_acc: 0.8333, loss_cls: 1.8880, loss: 1.8880, grad_norm: 19.0350
# 2022-12-08 02:18:21,117 - mmaction - INFO - Epoch [14][50/52]	lr: 9.375e-04, eta: 0:07:05, time: 1.333, data_time: 0.007, memory: 10390, top1_acc: 0.4333, top5_acc: 0.8667, loss_cls: 1.9144, loss: 1.9144, grad_norm: 17.8236
# 2022-12-08 02:18:33,692 - mmaction - INFO - Epoch [15][5/52]	lr: 9.375e-04, eta: 0:06:56, time: 2.053, data_time: 0.712, memory: 10390, top1_acc: 0.5667, top5_acc: 0.8667, loss_cls: 1.3201, loss: 1.3201, grad_norm: 13.6432
# 2022-12-08 02:18:40,366 - mmaction - INFO - Epoch [15][10/52]	lr: 9.375e-04, eta: 0:06:49, time: 1.335, data_time: 0.010, memory: 10390, top1_acc: 0.4333, top5_acc: 0.9333, loss_cls: 1.2908, loss: 1.2908, grad_norm: 14.8631
# 2022-12-08 02:18:47,072 - mmaction - INFO - Epoch [15][15/52]	lr: 9.375e-04, eta: 0:06:42, time: 1.341, data_time: 0.005, memory: 10390, top1_acc: 0.6000, top5_acc: 0.9333, loss_cls: 1.4578, loss: 1.4578, grad_norm: 14.6258
# 2022-12-08 02:18:53,792 - mmaction - INFO - Epoch [15][20/52]	lr: 9.375e-04, eta: 0:06:36, time: 1.344, data_time: 0.006, memory: 10390, top1_acc: 0.6333, top5_acc: 0.9000, loss_cls: 1.2127, loss: 1.2127, grad_norm: 14.2073
# 2022-12-08 02:19:00,564 - mmaction - INFO - Epoch [15][25/52]	lr: 9.375e-04, eta: 0:06:29, time: 1.354, data_time: 0.015, memory: 10390, top1_acc: 0.3333, top5_acc: 0.7667, loss_cls: 2.1807, loss: 2.1807, grad_norm: 17.8593
# 2022-12-08 02:19:07,295 - mmaction - INFO - Epoch [15][30/52]	lr: 9.375e-04, eta: 0:06:22, time: 1.346, data_time: 0.008, memory: 10390, top1_acc: 0.5333, top5_acc: 0.8000, loss_cls: 1.5299, loss: 1.5299, grad_norm: 14.3397
# 2022-12-08 02:19:14,097 - mmaction - INFO - Epoch [15][35/52]	lr: 9.375e-04, eta: 0:06:15, time: 1.360, data_time: 0.006, memory: 10390, top1_acc: 0.5667, top5_acc: 0.8667, loss_cls: 1.5741, loss: 1.5741, grad_norm: 16.6363
# 2022-12-08 02:19:20,763 - mmaction - INFO - Epoch [15][40/52]	lr: 9.375e-04, eta: 0:06:08, time: 1.333, data_time: 0.003, memory: 10390, top1_acc: 0.6333, top5_acc: 0.9333, loss_cls: 1.2406, loss: 1.2406, grad_norm: 14.0812
# 2022-12-08 02:19:27,474 - mmaction - INFO - Epoch [15][45/52]	lr: 9.375e-04, eta: 0:06:02, time: 1.342, data_time: 0.011, memory: 10390, top1_acc: 0.3667, top5_acc: 0.7333, loss_cls: 2.2656, loss: 2.2656, grad_norm: 18.8167
# 2022-12-08 02:19:34,102 - mmaction - INFO - Epoch [15][50/52]	lr: 9.375e-04, eta: 0:05:55, time: 1.326, data_time: 0.004, memory: 10390, top1_acc: 0.4000, top5_acc: 0.8000, loss_cls: 1.8873, loss: 1.8873, grad_norm: 19.1107
# 2022-12-08 02:19:36,413 - mmaction - INFO - Saving checkpoint at 15 epochs
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 93/93, 7.5 task/s, elapsed: 12s, ETA:     0s
# 2022-12-08 02:19:49,771 - mmaction - INFO - Evaluating top_k_accuracy ...
# 2022-12-08 02:19:49,776 - mmaction - INFO -
# top1_acc	0.3118
# top5_acc	0.6989
# 2022-12-08 02:19:49,780 - mmaction - INFO - Evaluating mean_class_accuracy ...
# 2022-12-08 02:19:49,782 - mmaction - INFO -
# mean_acc	0.3118
# 2022-12-08 02:19:49,830 - mmaction - INFO - The previous best checkpoint /content/mmaction2/tutorial_exps/best_top1_acc_epoch_10.pth was removed
# 2022-12-08 02:19:50,845 - mmaction - INFO - Now best checkpoint is saved as best_top1_acc_epoch_15.pth.
# 2022-12-08 02:19:50,847 - mmaction - INFO - Best top1_acc is 0.3118 at 15 epoch.
# 2022-12-08 02:19:50,853 - mmaction - INFO - Epoch(val) [15][16]	top1_acc: 0.3118, top5_acc: 0.6989, mean_class_accuracy: 0.3118
# 2022-12-08 02:20:00,907 - mmaction - INFO - Epoch [16][5/52]	lr: 9.375e-04, eta: 0:05:45, time: 2.009, data_time: 0.686, memory: 10390, top1_acc: 0.4667, top5_acc: 0.8000, loss_cls: 1.6685, loss: 1.6685, grad_norm: 16.2900
# 2022-12-08 02:20:07,611 - mmaction - INFO - Epoch [16][10/52]	lr: 9.375e-04, eta: 0:05:39, time: 1.341, data_time: 0.011, memory: 10390, top1_acc: 0.5000, top5_acc: 0.9333, loss_cls: 1.2874, loss: 1.2874, grad_norm: 14.6798
# 2022-12-08 02:20:14,390 - mmaction - INFO - Epoch [16][15/52]	lr: 9.375e-04, eta: 0:05:32, time: 1.356, data_time: 0.004, memory: 10390, top1_acc: 0.4000, top5_acc: 0.8333, loss_cls: 1.7481, loss: 1.7481, grad_norm: 15.0618
# 2022-12-08 02:20:21,275 - mmaction - INFO - Epoch [16][20/52]	lr: 9.375e-04, eta: 0:05:25, time: 1.377, data_time: 0.010, memory: 10390, top1_acc: 0.5000, top5_acc: 0.8333, loss_cls: 1.4630, loss: 1.4630, grad_norm: 16.7622
# 2022-12-08 02:20:28,145 - mmaction - INFO - Epoch [16][25/52]	lr: 9.375e-04, eta: 0:05:18, time: 1.374, data_time: 0.006, memory: 10390, top1_acc: 0.6333, top5_acc: 0.9000, loss_cls: 1.3412, loss: 1.3412, grad_norm: 17.0782
# 2022-12-08 02:20:34,885 - mmaction - INFO - Epoch [16][30/52]	lr: 9.375e-04, eta: 0:05:12, time: 1.348, data_time: 0.003, memory: 10390, top1_acc: 0.6667, top5_acc: 0.9333, loss_cls: 1.1895, loss: 1.1895, grad_norm: 15.7532
# 2022-12-08 02:20:41,587 - mmaction - INFO - Epoch [16][35/52]	lr: 9.375e-04, eta: 0:05:05, time: 1.340, data_time: 0.004, memory: 10390, top1_acc: 0.5333, top5_acc: 0.8333, loss_cls: 1.4777, loss: 1.4777, grad_norm: 17.0881
# 2022-12-08 02:20:48,218 - mmaction - INFO - Epoch [16][40/52]	lr: 9.375e-04, eta: 0:04:58, time: 1.326, data_time: 0.005, memory: 10390, top1_acc: 0.5667, top5_acc: 0.9333, loss_cls: 1.1875, loss: 1.1875, grad_norm: 15.9995
# 2022-12-08 02:20:54,887 - mmaction - INFO - Epoch [16][45/52]	lr: 9.375e-04, eta: 0:04:51, time: 1.334, data_time: 0.011, memory: 10390, top1_acc: 0.4000, top5_acc: 0.7667, loss_cls: 1.8577, loss: 1.8577, grad_norm: 17.6719
# 2022-12-08 02:21:01,508 - mmaction - INFO - Epoch [16][50/52]	lr: 9.375e-04, eta: 0:04:44, time: 1.324, data_time: 0.005, memory: 10390, top1_acc: 0.5667, top5_acc: 0.9000, loss_cls: 1.3412, loss: 1.3412, grad_norm: 16.3849
# 2022-12-08 02:21:13,875 - mmaction - INFO - Epoch [17][5/52]	lr: 9.375e-04, eta: 0:04:35, time: 1.996, data_time: 0.673, memory: 10390, top1_acc: 0.6667, top5_acc: 0.7333, loss_cls: 1.6288, loss: 1.6288, grad_norm: 15.5222
# 2022-12-08 02:21:20,602 - mmaction - INFO - Epoch [17][10/52]	lr: 9.375e-04, eta: 0:04:28, time: 1.344, data_time: 0.017, memory: 10390, top1_acc: 0.6333, top5_acc: 0.9000, loss_cls: 1.1951, loss: 1.1951, grad_norm: 14.9800
# 2022-12-08 02:21:27,303 - mmaction - INFO - Epoch [17][15/52]	lr: 9.375e-04, eta: 0:04:21, time: 1.342, data_time: 0.017, memory: 10390, top1_acc: 0.5333, top5_acc: 0.9000, loss_cls: 1.4202, loss: 1.4202, grad_norm: 19.0273
# 2022-12-08 02:21:34,026 - mmaction - INFO - Epoch [17][20/52]	lr: 9.375e-04, eta: 0:04:15, time: 1.344, data_time: 0.011, memory: 10390, top1_acc: 0.6667, top5_acc: 0.9000, loss_cls: 1.3131, loss: 1.3131, grad_norm: 13.6127
# 2022-12-08 02:21:40,788 - mmaction - INFO - Epoch [17][25/52]	lr: 9.375e-04, eta: 0:04:08, time: 1.351, data_time: 0.008, memory: 10390, top1_acc: 0.6000, top5_acc: 0.8333, loss_cls: 1.5099, loss: 1.5099, grad_norm: 18.9130
# 2022-12-08 02:21:47,575 - mmaction - INFO - Epoch [17][30/52]	lr: 9.375e-04, eta: 0:04:01, time: 1.359, data_time: 0.011, memory: 10390, top1_acc: 0.5000, top5_acc: 0.8667, loss_cls: 1.2753, loss: 1.2753, grad_norm: 13.0940
# 2022-12-08 02:21:54,335 - mmaction - INFO - Epoch [17][35/52]	lr: 9.375e-04, eta: 0:03:54, time: 1.352, data_time: 0.007, memory: 10390, top1_acc: 0.5000, top5_acc: 0.9333, loss_cls: 1.2219, loss: 1.2219, grad_norm: 14.7642
# 2022-12-08 02:22:01,057 - mmaction - INFO - Epoch [17][40/52]	lr: 9.375e-04, eta: 0:03:47, time: 1.344, data_time: 0.004, memory: 10390, top1_acc: 0.4667, top5_acc: 0.9000, loss_cls: 1.4157, loss: 1.4157, grad_norm: 16.8843
# 2022-12-08 02:22:07,785 - mmaction - INFO - Epoch [17][45/52]	lr: 9.375e-04, eta: 0:03:41, time: 1.346, data_time: 0.012, memory: 10390, top1_acc: 0.4333, top5_acc: 0.8000, loss_cls: 1.7091, loss: 1.7091, grad_norm: 18.9812
# 2022-12-08 02:22:14,419 - mmaction - INFO - Epoch [17][50/52]	lr: 9.375e-04, eta: 0:03:34, time: 1.327, data_time: 0.005, memory: 10390, top1_acc: 0.4333, top5_acc: 0.8667, loss_cls: 1.5927, loss: 1.5927, grad_norm: 17.6784
# 2022-12-08 02:22:27,410 - mmaction - INFO - Epoch [18][5/52]	lr: 9.375e-04, eta: 0:03:24, time: 2.131, data_time: 0.795, memory: 10390, top1_acc: 0.7333, top5_acc: 0.9333, loss_cls: 0.9879, loss: 0.9879, grad_norm: 11.5934
# 2022-12-08 02:22:34,044 - mmaction - INFO - Epoch [18][10/52]	lr: 9.375e-04, eta: 0:03:18, time: 1.329, data_time: 0.009, memory: 10390, top1_acc: 0.7000, top5_acc: 0.9667, loss_cls: 1.0038, loss: 1.0038, grad_norm: 15.0532
# 2022-12-08 02:22:40,735 - mmaction - INFO - Epoch [18][15/52]	lr: 9.375e-04, eta: 0:03:11, time: 1.338, data_time: 0.012, memory: 10390, top1_acc: 0.5667, top5_acc: 0.9667, loss_cls: 1.3224, loss: 1.3224, grad_norm: 15.3723
# 2022-12-08 02:22:47,408 - mmaction - INFO - Epoch [18][20/52]	lr: 9.375e-04, eta: 0:03:04, time: 1.335, data_time: 0.004, memory: 10390, top1_acc: 0.6333, top5_acc: 0.9000, loss_cls: 1.1823, loss: 1.1823, grad_norm: 15.6186
# 2022-12-08 02:22:54,111 - mmaction - INFO - Epoch [18][25/52]	lr: 9.375e-04, eta: 0:02:57, time: 1.341, data_time: 0.006, memory: 10390, top1_acc: 0.4667, top5_acc: 0.9333, loss_cls: 1.2658, loss: 1.2658, grad_norm: 15.9857
# 2022-12-08 02:23:00,865 - mmaction - INFO - Epoch [18][30/52]	lr: 9.375e-04, eta: 0:02:50, time: 1.351, data_time: 0.010, memory: 10390, top1_acc: 0.6667, top5_acc: 0.9333, loss_cls: 1.1402, loss: 1.1402, grad_norm: 15.4785
# 2022-12-08 02:23:07,624 - mmaction - INFO - Epoch [18][35/52]	lr: 9.375e-04, eta: 0:02:44, time: 1.352, data_time: 0.007, memory: 10390, top1_acc: 0.6000, top5_acc: 0.9000, loss_cls: 1.2470, loss: 1.2470, grad_norm: 16.4829
# 2022-12-08 02:23:14,307 - mmaction - INFO - Epoch [18][40/52]	lr: 9.375e-04, eta: 0:02:37, time: 1.336, data_time: 0.004, memory: 10390, top1_acc: 0.6667, top5_acc: 0.9667, loss_cls: 1.0727, loss: 1.0727, grad_norm: 15.4436
# 2022-12-08 02:23:20,980 - mmaction - INFO - Epoch [18][45/52]	lr: 9.375e-04, eta: 0:02:30, time: 1.335, data_time: 0.004, memory: 10390, top1_acc: 0.5333, top5_acc: 0.8333, loss_cls: 1.6201, loss: 1.6201, grad_norm: 16.5112
# 2022-12-08 02:23:27,605 - mmaction - INFO - Epoch [18][50/52]	lr: 9.375e-04, eta: 0:02:23, time: 1.325, data_time: 0.002, memory: 10390, top1_acc: 0.5667, top5_acc: 0.9000, loss_cls: 1.3589, loss: 1.3589, grad_norm: 15.6041
# 2022-12-08 02:23:39,627 - mmaction - INFO - Epoch [19][5/52]	lr: 9.375e-04, eta: 0:02:14, time: 1.941, data_time: 0.605, memory: 10390, top1_acc: 0.6667, top5_acc: 0.9000, loss_cls: 1.2060, loss: 1.2060, grad_norm: 13.9314
# 2022-12-08 02:23:46,297 - mmaction - INFO - Epoch [19][10/52]	lr: 9.375e-04, eta: 0:02:07, time: 1.334, data_time: 0.004, memory: 10390, top1_acc: 0.6667, top5_acc: 1.0000, loss_cls: 0.8043, loss: 0.8043, grad_norm: 14.2841
# 2022-12-08 02:23:52,993 - mmaction - INFO - Epoch [19][15/52]	lr: 9.375e-04, eta: 0:02:00, time: 1.338, data_time: 0.005, memory: 10390, top1_acc: 0.6333, top5_acc: 0.9333, loss_cls: 1.1646, loss: 1.1646, grad_norm: 13.8094
# 2022-12-08 02:23:59,660 - mmaction - INFO - Epoch [19][20/52]	lr: 9.375e-04, eta: 0:01:53, time: 1.335, data_time: 0.006, memory: 10390, top1_acc: 0.7000, top5_acc: 1.0000, loss_cls: 0.9401, loss: 0.9401, grad_norm: 17.0565
# 2022-12-08 02:24:06,361 - mmaction - INFO - Epoch [19][25/52]	lr: 9.375e-04, eta: 0:01:47, time: 1.340, data_time: 0.007, memory: 10390, top1_acc: 0.6667, top5_acc: 0.9333, loss_cls: 1.0559, loss: 1.0559, grad_norm: 16.4682
# 2022-12-08 02:24:13,049 - mmaction - INFO - Epoch [19][30/52]	lr: 9.375e-04, eta: 0:01:40, time: 1.336, data_time: 0.007, memory: 10390, top1_acc: 0.5667, top5_acc: 0.9000, loss_cls: 1.2447, loss: 1.2447, grad_norm: 15.6676
# 2022-12-08 02:24:19,736 - mmaction - INFO - Epoch [19][35/52]	lr: 9.375e-04, eta: 0:01:33, time: 1.339, data_time: 0.005, memory: 10390, top1_acc: 0.7000, top5_acc: 0.9000, loss_cls: 1.1520, loss: 1.1520, grad_norm: 14.2142
# 2022-12-08 02:24:26,477 - mmaction - INFO - Epoch [19][40/52]	lr: 9.375e-04, eta: 0:01:26, time: 1.348, data_time: 0.011, memory: 10390, top1_acc: 0.5667, top5_acc: 0.9000, loss_cls: 1.3749, loss: 1.3749, grad_norm: 14.0361
# 2022-12-08 02:24:33,189 - mmaction - INFO - Epoch [19][45/52]	lr: 9.375e-04, eta: 0:01:20, time: 1.343, data_time: 0.014, memory: 10390, top1_acc: 0.5667, top5_acc: 0.7667, loss_cls: 1.5027, loss: 1.5027, grad_norm: 17.7478
# 2022-12-08 02:24:39,853 - mmaction - INFO - Epoch [19][50/52]	lr: 9.375e-04, eta: 0:01:13, time: 1.333, data_time: 0.008, memory: 10390, top1_acc: 0.4000, top5_acc: 0.8333, loss_cls: 1.5991, loss: 1.5991, grad_norm: 18.8704
# 2022-12-08 02:24:52,231 - mmaction - INFO - Epoch [20][5/52]	lr: 9.375e-04, eta: 0:01:03, time: 2.010, data_time: 0.685, memory: 10390, top1_acc: 0.8000, top5_acc: 0.8667, loss_cls: 0.9581, loss: 0.9581, grad_norm: 10.9868
# 2022-12-08 02:24:58,962 - mmaction - INFO - Epoch [20][10/52]	lr: 9.375e-04, eta: 0:00:56, time: 1.346, data_time: 0.014, memory: 10390, top1_acc: 0.5000, top5_acc: 0.7667, loss_cls: 1.6162, loss: 1.6162, grad_norm: 18.7134
# 2022-12-08 02:25:05,768 - mmaction - INFO - Epoch [20][15/52]	lr: 9.375e-04, eta: 0:00:50, time: 1.361, data_time: 0.004, memory: 10390, top1_acc: 0.5667, top5_acc: 0.8000, loss_cls: 1.3820, loss: 1.3820, grad_norm: 16.5395
# 2022-12-08 02:25:12,477 - mmaction - INFO - Epoch [20][20/52]	lr: 9.375e-04, eta: 0:00:43, time: 1.340, data_time: 0.006, memory: 10390, top1_acc: 0.6667, top5_acc: 0.9667, loss_cls: 1.0637, loss: 1.0637, grad_norm: 18.2344
# 2022-12-08 02:25:19,181 - mmaction - INFO - Epoch [20][25/52]	lr: 9.375e-04, eta: 0:00:36, time: 1.342, data_time: 0.009, memory: 10390, top1_acc: 0.7333, top5_acc: 0.9667, loss_cls: 0.9176, loss: 0.9176, grad_norm: 15.2512
# 2022-12-08 02:25:25,898 - mmaction - INFO - Epoch [20][30/52]	lr: 9.375e-04, eta: 0:00:29, time: 1.343, data_time: 0.008, memory: 10390, top1_acc: 0.7000, top5_acc: 0.9667, loss_cls: 1.0036, loss: 1.0036, grad_norm: 14.5718
# 2022-12-08 02:25:32,615 - mmaction - INFO - Epoch [20][35/52]	lr: 9.375e-04, eta: 0:00:23, time: 1.342, data_time: 0.007, memory: 10390, top1_acc: 0.5333, top5_acc: 1.0000, loss_cls: 1.0733, loss: 1.0733, grad_norm: 16.5640
# 2022-12-08 02:25:39,290 - mmaction - INFO - Epoch [20][40/52]	lr: 9.375e-04, eta: 0:00:16, time: 1.337, data_time: 0.006, memory: 10390, top1_acc: 0.7333, top5_acc: 0.9333, loss_cls: 0.8655, loss: 0.8655, grad_norm: 11.7130
# 2022-12-08 02:25:46,027 - mmaction - INFO - Epoch [20][45/52]	lr: 9.375e-04, eta: 0:00:09, time: 1.347, data_time: 0.009, memory: 10390, top1_acc: 0.6000, top5_acc: 0.8000, loss_cls: 1.3987, loss: 1.3987, grad_norm: 18.1904
# 2022-12-08 02:25:52,690 - mmaction - INFO - Epoch [20][50/52]	lr: 9.375e-04, eta: 0:00:02, time: 1.333, data_time: 0.006, memory: 10390, top1_acc: 0.5333, top5_acc: 0.9667, loss_cls: 1.2954, loss: 1.2954, grad_norm: 18.9558
# 2022-12-08 02:25:55,022 - mmaction - INFO - Saving checkpoint at 20 epochs
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 93/93, 8.6 task/s, elapsed: 11s, ETA:     0s
# 2022-12-08 02:26:06,871 - mmaction - INFO - Evaluating top_k_accuracy ...
# 2022-12-08 02:26:06,877 - mmaction - INFO -
# top1_acc	0.3011
# top5_acc	0.6559
# 2022-12-08 02:26:06,879 - mmaction - INFO - Evaluating mean_class_accuracy ...
# 2022-12-08 02:26:06,886 - mmaction - INFO -
# mean_acc	0.3011
# 2022-12-08 02:26:06,888 - mmaction - INFO - Epoch(val) [20][16]	top1_acc: 0.3011, top5_acc: 0.6559, mean_class_accuracy: 0.3011

# %%
# !cp -r ./tutorial_exps ../drive/MyDrive/IEMS5910/logs_ouput/

# %%
from mmaction.apis import single_gpu_test
from mmaction.datasets import build_dataloader
from mmcv.parallel import MMDataParallel

# Build a test dataloader
dataset = build_dataset(cfg.data.test, dict(test_mode=True))
data_loader = build_dataloader(
        dataset,
        videos_per_gpu=1,
        workers_per_gpu=cfg.data.workers_per_gpu,
        dist=False,
        shuffle=False)
modelPL = MMDataParallel(model, device_ids=[0])
outputs = single_gpu_test(modelPL, data_loader)

eval_config = cfg.evaluation
try:
  eval_config.pop('interval')
except:
  pass
eval_res = dataset.evaluate(outputs, **eval_config)
for name, val in eval_res.items():
    print(f'{name}: {val:.04f}')

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
# model.backbone.conv1.conv = torch.nn.Conv2d(1,64,kernel_size=(7,7), stride=(2,2), padding=(3,3),bias=False)
